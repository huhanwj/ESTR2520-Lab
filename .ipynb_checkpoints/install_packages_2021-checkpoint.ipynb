# %% [markdown]
# This code installs the necessary packages for FTEC2101/ESTR2520:

# %%
using Pkg

Pkg.add(Pkg.PackageSpec(;name="JuMP", version="0.21.5"))
Pkg.add(Pkg.PackageSpec(;name="GLPK", version="0.14.4"))
Pkg.add(Pkg.PackageSpec(;name="CSV", version="0.8.2"))
Pkg.add(Pkg.PackageSpec(;name="Plots", version="1.4.3"))
Pkg.add(Pkg.PackageSpec(;name="ECOS", version="0.12.2"))
Pkg.add(Pkg.PackageSpec(;name="Glob", version="1.3.0"))
Pkg.add(Pkg.PackageSpec(;name="Ipopt", version="0.6.5"))
Pkg.add(Pkg.PackageSpec(;name="Juniper", version="0.6.5"))
Pkg.add(Pkg.PackageSpec(;name="DataFrames", version="0.22.5"))

Pkg.API.precompile()
# Out:
#   Updating registry at `C:\Users\huhan\.julia\registries\General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 % % Resolving package versions...
#  Installed Calculus ───────────── v0.5.1
#  Installed ZipFile ────────────── v0.8.4
#  Installed NetworkOptions ─────── v1.2.0
#  Installed SpecialFunctions ───── v0.8.0
#  Installed BenchmarkTools ─────── v0.7.0
#  Installed ForwardDiff ────────── v0.10.18
#  Installed JuMP ───────────────── v0.21.5
#  Installed MathOptInterface ───── v0.9.21
#  Installed OrderedCollections ─── v1.4.0
#  Installed URIs ───────────────── v1.3.0
#  Installed MutableArithmetics ─── v0.2.18
#  Installed BinDeps ────────────── v1.0.2
#  Installed CodecBzip2 ─────────── v0.6.0
#  Installed DiffRules ──────────── v1.0.2
#  Installed HTTP ───────────────── v0.9.8
#  Installed TranscodingStreams ─── v0.9.5
#  Installed CommonSubexpressions ─ v0.3.0
#  Installed CodecZlib ──────────── v0.6.0
#  Installed MacroTools ─────────── v0.5.6
#  Installed DiffResults ────────── v1.0.3
#  Installed IniFile ────────────── v0.5.0
#  Installed JSONSchema ─────────── v0.3.3
#  Installed NaNMath ────────────── v0.3.5
#  Installed URIParser ──────────── v0.4.1
#  Installed DataStructures ─────── v0.18.9
#  Installed Compat ─────────────── v3.28.0
#  Installed StaticArrays ───────── v1.1.2
#   Updating `C:\Users\huhan\.julia\environments\v1.1\Project.toml`
#   [4076af6c] + JuMP v0.21.5
#   Updating `C:\Users\huhan\.julia\environments\v1.1\Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v0.7.0
#   [9e28174c] + BinDeps v1.0.2
#   [49dc2e85] + Calculus v0.5.1
#   [523fee87] + CodecBzip2 v0.6.0
#   [944b1d66] + CodecZlib v0.6.0
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v3.28.0
#   [864edb3b] + DataStructures v0.18.9
#   [163ba53b] + DiffResults v1.0.3
#   [b552c78f] + DiffRules v1.0.2
#   [f6369f11] + ForwardDiff v0.10.18
#   [cd3eb016] + HTTP v0.9.8
#   [83e8ac13] + IniFile v0.5.0
#   [7d188eb4] + JSONSchema v0.3.3
#   [4076af6c] + JuMP v0.21.5
#   [1914dd2f] + MacroTools v0.5.6
#   [b8f27783] + MathOptInterface v0.9.21
#   [d8a4904e] + MutableArithmetics v0.2.18
#   [77ba4419] + NaNMath v0.3.5
#   [ca575930] + NetworkOptions v1.2.0
#   [bac558e1] + OrderedCollections v1.4.0
#   [276daf66] + SpecialFunctions v0.8.0
#   [90137ffa] + StaticArrays v1.1.2
#   [3bb67fe8] + TranscodingStreams v0.9.5
#   [30578b45] + URIParser v0.4.1
#   [5c2747f8] + URIs v1.3.0
#   [a5390f91] + ZipFile v0.8.4
#   [8bb1440f] + DelimitedFiles
#   [37e2e46d] + LinearAlgebra
#   [1a1011a3] + SharedArrays
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   Building SpecialFunctions → `C:\Users\huhan\.julia\packages\SpecialFunctions\ne2iw\deps\build.log`
#   Building ZipFile ─────────→ `C:\Users\huhan\.julia\packages\ZipFile\DW0Qr\deps\build.log`
#   Building CodecBzip2 ──────→ `C:\Users\huhan\.julia\packages\CodecBzip2\T5yr7\deps\build.log`
#   Building CodecZlib ───────→ `C:\Users\huhan\.julia\packages\CodecZlib\5t9zO\deps\build.log`
#  Resolving package versions...
#  Installed Artifacts ─── v1.3.0
#  Installed CEnum ─────── v0.4.1
#  Installed GLPK_jll ──── v4.64.0+0
#  Installed GMP_jll ───── v6.1.2+6
#  Installed Preferences ─ v1.2.1
#  Installed JLLWrappers ─ v1.3.0
#  Installed TOML ──────── v1.0.3
#  Installed GLPK ──────── v0.14.4
#   Updating `C:\Users\huhan\.julia\environments\v1.1\Project.toml`
#   [60bf3e95] + GLPK v0.14.4
#   Updating `C:\Users\huhan\.julia\environments\v1.1\Manifest.toml`
#   [56f22d72] + Artifacts v1.3.0
#   [fa961155] + CEnum v0.4.1
#   [60bf3e95] + GLPK v0.14.4
#   [e8aa6df9] + GLPK_jll v4.64.0+0
#   [781609d7] + GMP_jll v6.1.2+6
#   [692b3bcd] + JLLWrappers v1.3.0
#   [21216c6a] + Preferences v1.2.1
#   [fa267f1f] + TOML v1.0.3
#   Building GLPK → `C:\Users\huhan\.julia\packages\GLPK\G3GZQ\deps\build.log`
#  Resolving package versions...
#  Installed DataValueInterfaces ───────── v1.0.0
#  Installed PooledArrays ──────────────── v0.5.3
#  Installed SentinelArrays ────────────── v1.2.16
#  Installed DataAPI ───────────────────── v1.6.0
#  Installed IteratorInterfaceExtensions ─ v1.0.0
#  Installed TableTraits ───────────────── v1.0.1
#  Installed Tables ────────────────────── v1.4.2
#  Installed CSV ───────────────────────── v0.8.2
#   Updating `C:\Users\huhan\.julia\environments\v1.1\Project.toml`
#   [336ed68f] + CSV v0.8.2
#   Updating `C:\Users\huhan\.julia\environments\v1.1\Manifest.toml`
#   [336ed68f] + CSV v0.8.2
#   [9a962f9c] + DataAPI v1.6.0
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [2dfb63ee] + PooledArrays v0.5.3
#   [91c51154] + SentinelArrays v1.2.16
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.4.2
#  Resolving package versions...
#  Installed Missings ────────── v1.0.0
#  Installed RecipesBase ─────── v1.1.1
#  Installed FFMPEG ──────────── v0.2.4
#  Installed RecipesPipeline ─── v0.1.13
#  Installed Plots ───────────── v1.4.3
#  Installed ColorTypes ──────── v0.10.12
#  Installed PlotThemes ──────── v2.0.1
#  Installed GR ──────────────── v0.50.1
#  Installed Requires ────────── v1.1.3
#  Installed Grisu ───────────── v1.0.2
#  Installed StatsBase ───────── v0.33.8
#  Installed SortingAlgorithms ─ v1.0.0
#  Installed Contour ─────────── v0.5.7
#  Installed Showoff ─────────── v0.3.2
#  Installed StatsAPI ────────── v1.0.0
#  Installed Measures ────────── v0.3.1
#  Installed HTTP ────────────── v0.8.19
#  Installed FixedPointNumbers ─ v0.8.4
#  Installed PlotUtils ───────── v1.0.10
#  Installed Reexport ────────── v0.2.0
#  Installed Colors ──────────── v0.12.8
#  Installed GeometryTypes ───── v0.8.4
#  Installed ColorSchemes ────── v3.12.1
#   Updating `C:\Users\huhan\.julia\environments\v1.1\Project.toml`
#   [91a5bcdd] + Plots v1.4.3
#   Updating `C:\Users\huhan\.julia\environments\v1.1\Manifest.toml`
#   [35d6a980] + ColorSchemes v3.12.1
#   [3da002f7] + ColorTypes v0.10.12
#   [5ae59095] + Colors v0.12.8
#   [d38c429a] + Contour v0.5.7
#   [c87230d0] + FFMPEG v0.2.4
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [28b8d3ca] + GR v0.50.1
#   [4d00f742] + GeometryTypes v0.8.4
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] ↓ HTTP v0.9.8 ⇒ v0.8.19
#   [442fdcdd] + Measures v0.3.1
#   [e1d29d7a] + Missings v1.0.0
#   [ca575930] - NetworkOptions v1.2.0
#   [ccf2f8ad] + PlotThemes v2.0.1
#   [995b91a9] + PlotUtils v1.0.10
#   [91a5bcdd] + Plots v1.4.3
#   [3cdcf5f2] + RecipesBase v1.1.1
#   [01d81517] + RecipesPipeline v0.1.13
#   [189a3867] + Reexport v0.2.0
#   [ae029012] + Requires v1.1.3
#   [992d4aef] + Showoff v0.3.2
#   [a2af1166] + SortingAlgorithms v1.0.0
#   [82ae8749] + StatsAPI v1.0.0
#   [2913bbd2] + StatsBase v0.33.8
#   [5c2747f8] - URIs v1.3.0
#   Building GR ────→ `C:\Users\huhan\.julia\packages\GR\Atztx\deps\build.log`
#   Building FFMPEG → `C:\Users\huhan\.julia\packages\FFMPEG\guN1x\deps\build.log`
